# %%
import numpy as np
import pandas as pd

# %%
events = pd.read_csv('../data/raw/events.csv')
categories = pd.read_csv("../data/raw/category_tree.csv")
properties1 = pd.read_csv("../data/raw/item_properties_part1.csv")
properties2 = pd.read_csv("../data/raw/item_properties_part2.csv")

# %%
print("Events:", events.shape)
print("Categories:", categories.shape)
print("Properties Part 1:", properties1.shape)
print("Properties Part 2:", properties2.shape)
# Out:
# Events: (2756101, 5)
# Categories: (1669, 2)
# Properties Part 1: (10999999, 4)
# Properties Part 2: (9275903, 4)

# %%
events.head()
events.info()
events.describe(include='all')
events.isnull().sum()
events.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2756101 entries, 0 to 2756100
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      int64
#  1   visitorid      int64
#  2   event          str
#  3   itemid         int64
#  4   transactionid  float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 105.1 MB
# np.int64(460)

# %%
categories.head()
categories.info()
categories.describe(include='all')
categories.isnull().sum()
categories.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categoryid  1669 non-null   int64
#  1   parentid    1644 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 26.2 KB
# np.int64(0)

# %%
properties1.head()
properties1.info()
properties1.describe(include='all')
properties1.isnull().sum()
properties1.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10999999 entries, 0 to 10999998
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
#  1   itemid     int64
#  2   property   str
#  3   value      str
# dtypes: int64(2), str(2)
# memory usage: 335.7 MB
# np.int64(0)

# %%
properties2.head()
properties2.info()
properties2.describe(include='all')
properties2.isnull().sum()
properties2.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9275903 entries, 0 to 9275902
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
#  1   itemid     int64
#  2   property   str
#  3   value      str
# dtypes: int64(2), str(2)
# memory usage: 283.1 MB
# np.int64(0)

# %%
print(events.isnull().sum())
print(categories.isnull().sum())
print(properties1.isnull().sum())
print(properties2.isnull().sum())
# Out:
# timestamp              0
# visitorid              0
# event                  0
# itemid                 0
# transactionid    2733644
# dtype: int64
# categoryid     0
# parentid      25
# dtype: int64
# timestamp    0
# itemid       0
# property     0
# value        0
# dtype: int64
# timestamp    0
# itemid       0
# property     0
# value        0
# dtype: int64

# %%
print(events.duplicated().sum())
print(categories.duplicated().sum())
print(properties1.duplicated().sum())
print(properties2.duplicated().sum())
# Out:
# 460
# 0
# 0
# 0

# %%
events['event'].value_counts()
# Out:
# event
# view           2664312
# addtocart        69332
# transaction      22457
# Name: count, dtype: int64

# %%
properties1['property'].value_counts()
# Out:
# property
# 888           1629817
# 790            970800
# available      817387
# categoryid     426305
# 6              343207
#                ...
# 598                 1
# 244                 1
# 424                 1
# 494                 1
# 712                 1
# Name: count, Length: 1097, dtype: int64

# %%
properties2['property'].value_counts()
# Out:
# property
# 888           1370581
# 790            819716
# available      686252
# categoryid     361909
# 6              288264
#                ...
# 494                 1
# 57                  1
# 1091                1
# 522                 1
# 769                 1
# Name: count, Length: 1094, dtype: int64
